# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from utils import *
import pandas as pd

# %%
fdir = '/home/users/liujx/bridge_lamb3/das_bhm/'
das = np.load(f"{fdir}data/extfig3.npz")
x = das['x']
t = das['t']
data = das['data']

# %%
plot_xcorr(data, t_axis=t, x_axis=x, ax=None, figsize=(9,6),
           cmap='seismic', fontsize=24, tickfont=24, 
           fig_dir=f'{fdir}figs/', fig_name='extfig3c.pdf',
           x_lim=[0,110], y_lim=[0.5,0])
# Out:
# /home/users/liujx/bridge_lamb3/das_bhm/figs/extfig3c.pdf has saved...

# %%
fv_maps = np.load(f'{fdir}data/extfig3d.npz')['fv_maps']
f_axis=np.load(f'{fdir}data/extfig3d.npz')['f_axis']
v_axis=np.load(f'{fdir}data/extfig3d.npz')['v_axis']
# dispersion_byancheong
fs = 500
plot_fv_map(np.flip(fv_maps,axis=0), f_axis, v_axis, df=None, vs=2350,
            norm=True, ax=None, pclip=100, fig_dir=f'{fdir}figs/',fig_name='extfig3d.pdf',
            fontsize=20, tickfont=20, figsize=(9,6))
# Out:
# saving /home/users/liujx/bridge_lamb3/das_bhm/figs/extfig3d.pdf...
