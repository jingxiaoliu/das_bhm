# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from utils import *
import pandas as pd

# %%
fdir = '/home/users/liujx/bridge_lamb3/das_bhm/'
# das = np.load(f"{fdir}data/fig3.npz")
# x = das['x']
# t = das['t']
# data = das['data']

# %%
# plot_xcorr(data, t_axis=t, x_axis=x, ax=None, figsize=(9,5),
#            cmap='seismic', fontsize=24, tickfont=24, 
#            fig_dir=f'{fdir}figs/', fig_name='fig3d.pdf',
#            x_lim=[0,725], y_lim=[0.3,0])
# plot_xcorr(data, t_axis=t, x_axis=x, ax=None, figsize=(9,5),
#            cmap='seismic', fontsize=24, tickfont=24, 
#            fig_dir=f'{fdir}figs/', fig_name='fig3e.pdf',
#            x_lim=[0,725], y_lim=[2,0])

# %%
df_comsol=pd.read_csv(f"{fdir}data/fig3f2.csv")
fv_maps = np.load(f'{fdir}data/fig3f1.npz')['fv_maps']
f_axis=np.load(f'{fdir}data/fig3f1.npz')['f_axis']
v_axis=np.load(f'{fdir}data/fig3f1.npz')['v_axis']
# dispersion_byancheong
fs = 500
plot_fv_map(np.flip(fv_maps,axis=0), f_axis, v_axis, df_comsol, vs=2350,
            norm=True, ax=None, pclip=100, fig_dir=f'{fdir}figs/',fig_name='fig3f.pdf',
            fontsize=20, tickfont=20, figsize=(9,9))
# Out:
# saving /home/users/liujx/bridge_lamb3/das_bhm/figs/fig3f.pdf...

# %%
df_comsol=pd.read_csv(f"{fdir}data/supfig2.csv")
fv_maps = np.load(f'{fdir}data/fig3f1.npz')['fv_maps']
f_axis=np.load(f'{fdir}data/fig3f1.npz')['f_axis']
v_axis=np.load(f'{fdir}data/fig3f1.npz')['v_axis']
# dispersion_byancheong
fs = 500
plot_fv_map(np.flip(fv_maps,axis=0), f_axis, v_axis, df_comsol, vs=2350,
            norm=True, ax=None, pclip=100, fig_dir=f'{fdir}figs/',fig_name='supfig2.pdf',
            fontsize=20, tickfont=20, figsize=(9,9))
# Out:
# saving /home/users/liujx/bridge_lamb3/das_bhm/figs/supfig2.pdf...
