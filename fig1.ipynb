# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from utils import *

# %%
# !pwd
# Out:
# /home/users/liujx/bridge_lamb3/das_bhm

# %%
fdir = '/home/users/liujx/bridge_lamb3/das_bhm/'
das = np.load(f"{fdir}data/fig1.npz")
x = das['x']
t = das['t']
date_t = das['date_t']
data = das['data']
data_norm = 2 * (data - data.min()) / (data.max() - data.min()) - 1

# %%
fig, ax = plt.subplots(figsize=(4.1, 6))
plt.plot(data_norm[50,:],date_t,'k')
plt.ylabel('Time (s)',fontsize=24)
plt.xlabel('Normalized DAS',fontsize=24)
plt.ylim([15,0])
ax.tick_params(axis='both', which='major', labelsize=20)
plt.tight_layout()
plt.savefig(f'{fdir}figs/fig1b.pdf')

# %%
_start_time = datetime(2023, 9, 20, 0, 15, 50)
duration = 0.25
_end_time = _start_time + timedelta(minutes=duration)

plot_das_data(t,x,data.T, t_max=60*duration,
              start_time=_start_time, end_time=_end_time, lb_perc = 1, up_perc = 99, 
              save_fig=f'{fdir}figs/fig1c.pdf')
