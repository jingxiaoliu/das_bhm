# %%
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
from utils import *
import pandas as pd

# %%
fdir = '/home/users/liujx/bridge_lamb3/das_bhm/'
das = np.load(f"{fdir}data/extfig2.npz")
x = das['x']
t = das['t']
data = das['data']

# %%
plot_xcorr(data, t_axis=t, x_axis=x, ax=None, figsize=(9,5),
           cmap='seismic', fontsize=24, tickfont=24, 
           fig_dir=f'{fdir}figs/', fig_name='extfig2d.pdf',
           x_lim=[0,725], y_lim=[2,0])
plot_xcorr(data, t_axis=t, x_axis=x, ax=None, figsize=(9,5),
           cmap='seismic', fontsize=24, tickfont=24, 
           fig_dir=f'{fdir}figs/', fig_name='extfig2e.pdf',
           x_lim=[0,725], y_lim=[0.3,0])
# Out:
# /home/users/liujx/bridge_lamb3/das_bhm/figs/extfig2d.pdf has saved...
# /home/users/liujx/bridge_lamb3/das_bhm/figs/extfig2e.pdf has saved...

# %%
df_comsol=pd.read_csv(f"{fdir}data/extfig2f2.csv")
fv_maps = np.load(f'{fdir}data/extfig2f1.npz')['fv_maps']
f_axis=np.load(f'{fdir}data/extfig2f1.npz')['f_axis']
v_axis=np.load(f'{fdir}data/extfig2f1.npz')['v_axis']
# dispersion_byancheong
fs = 500
plot_fv_map(np.flip(fv_maps,axis=0), f_axis, v_axis, df_comsol, vs=2000,
            norm=True, ax=None, pclip=100, fig_dir=f'{fdir}figs/',fig_name='extfig2f.pdf',
            fontsize=20, tickfont=20, figsize=(9,9))
# Out:
# saving /home/users/liujx/bridge_lamb3/das_bhm/figs/extfig2f.pdf...
